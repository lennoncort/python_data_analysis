# %%
import numpy as np
a = np.array([0,1,2,3,4])
a[0:3]=100,200,300
a
# Out:
# array([100, 200, 300,   3,   4])

# %%
u = np.array([2,5])
v = np.array([3,7])

z = u * v
#x = np.dot(u,v)
print(z,x)
y = u + 2
y
# Out:
# [ 6 35] 41
# array([4, 7])

# %%
# just playing with waves
import matplotlib.pyplot as plt
import numpy as np

a=5 #this is a dumping factor
x = np.linspace(0,4*np.pi,100)
y = np.exp(-x/a)*np.cos(x) #we include a decrese of the amplitude with the dumping factor

plt.plot(x,y)

# %%
arr = np.array([1, 2, 3, 4, 5, 6, 7])

print(arr[3:])
# Out:
# [4 5 6 7]
